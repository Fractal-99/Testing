# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Syed Ahmed Faran</b>
#
# Freelancing

# %% [markdown]
# *I am interested in Data Science as I have experience with probability theory and statistics. I have brief experience of working in Python and I want to levarage that experience.*

# %% [markdown]
# ### The dummy code below adds two integers.

# %%
a=1;
b=1;
c=a+b;
print(c)
# Out:
# 2

# %% [markdown]
# ***
# This is horizontal rule
# ***
#
# * Bullet 1
# * Bullet 2
# * Bullet 3
#
# 1. First item
# 2. Second item
# 3. Third item
#
# | Table    | Quantity|
# | ----------- | ----------- |
# | item 1    | 20    |
# | item 2   | 30        |
#
# Hyperlink: Useful information about Markdown is available on [Markdownguide](https://www.markdownguide.org/)
#
# ~~End of task.~~
